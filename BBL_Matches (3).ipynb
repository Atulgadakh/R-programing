# %%
library(dplyr)
library(ggplot2)

# %%
bbl=read.csv("/BBL matches.csv")

# %%
head(bbl,5)
# Out:
#   id     city      date       player_of_match
# 1 524915 Sydney    12/16/2011 BJ Haddin
# 2 524916 Melbourne 12/17/2011 DA Warner
# 3 524917 Adelaide  12/18/2011 M Klinger
# 4 524918 Perth     12/18/2011 BW Hilfenhaus
# 5 524919 Brisbane  12/20/2011 RJ Quiney
#   venue                                        neutral_venue team1
# 1 Sydney Cricket Ground                        0             Sydney Sixers
# 2 Melbourne Cricket Ground                     0             Melbourne Stars
# 3 Adelaide Oval                                0             Adelaide Strikers
# 4 Western Australia Cricket Association Ground 0             Perth Scorchers
# 5 Brisbane Cricket Ground, Woolloongabba       0             Brisbane Heat
#   team2               toss_winner         toss_decision winner
# 1 Brisbane Heat       Brisbane Heat       bat           Sydney Sixers
# 2 Sydney Thunder      Sydney Thunder      field         Sydney Thunder
# ...

# %%
is.na(bbl)
# Out:
#       id    city  date  player_of_match venue neutral_venue team1 team2
#  [1,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
#  [2,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
#  [3,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
#  [4,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
#  [5,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
#  [6,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
#  [7,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
#  [8,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
#  [9,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
# [10,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
# [11,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
# [12,] FALSE FALSE FALSE FALSE           FALSE FALSE         FALSE FALSE
# ...

# %%
sum(is.na(bbl))
# Out:
# [1] 364

# %%
bbl=na.omit(bbl)

# %%
head(bbl,5)
# Out:
#    id     city     date       player_of_match
# 16 524933 Sydney   1/8/2012   MA Starc
# 32 571236 Perth    12/12/2012 SL Malinga
# 37 571241 Brisbane 12/18/2012 NM Coulter-Nile
# 54 571265 Perth    2/5/2013   SE Marsh
# 88 654097 Sydney   2/5/2014   CJ Simmons
#    venue                                        neutral_venue team1
# 16 Stadium Australia                            0             Sydney Thunder
# 32 Western Australia Cricket Association Ground 0             Perth Scorchers
# 37 Brisbane Cricket Ground, Woolloongabba       0             Brisbane Heat
# 54 Western Australia Cricket Association Ground 0             Perth Scorchers
# 88 Sydney Cricket Ground                        0             Sydney Sixers
#    team2           toss_winner     toss_decision winner          result
# 16 Sydney Sixers   Sydney Sixers   bat           Sydney Sixers   runs
# 32 Melbourne Stars Melbourne Stars field         Melbourne Stars runs
# ...

# %%
sum(is.na(bbl))
# Out:
# [1] 0

# %%
count(bbl %>% group_by(player_of_match))
# Out:
#    player_of_match n
# 1  AD Hales        1
# 2  AI Ross         1
# 3  CA Lynn         1
# 4  CH Morris       1
# 5  CJ Simmons      1
# 6  DP Hughes       1
# 7  DR Sams         1
# 8  GB Hogg         1
# 9  J Weatherald    1
# 10 MA Starc        1
# 11 MC Henriques    1
# 12 NM Coulter-Nile 2
# 13 PJ Cummins      1
# 14 SB Harper       1
# 15 SE Marsh        1
# 16 SL Malinga      1
# 17 T Banton        1

# %%
options(repr.plot.height = 10)
options(repr.plot.width = 12)
ggplot(data = bbl,aes(x=player_of_match,fill=player_of_match)) + geom_bar()
# Out:
# plot without title

# %%
install.packages("ggplot2")
install.packages("dplyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
head(bbl,5)
# Out:
#    id     city     date       player_of_match
# 16 524933 Sydney   1/8/2012   MA Starc
# 32 571236 Perth    12/12/2012 SL Malinga
# 37 571241 Brisbane 12/18/2012 NM Coulter-Nile
# 54 571265 Perth    2/5/2013   SE Marsh
# 88 654097 Sydney   2/5/2014   CJ Simmons
#    venue                                        neutral_venue team1
# 16 Stadium Australia                            0             Sydney Thunder
# 32 Western Australia Cricket Association Ground 0             Perth Scorchers
# 37 Brisbane Cricket Ground, Woolloongabba       0             Brisbane Heat
# 54 Western Australia Cricket Association Ground 0             Perth Scorchers
# 88 Sydney Cricket Ground                        0             Sydney Sixers
#    team2           toss_winner     toss_decision winner          result
# 16 Sydney Sixers   Sydney Sixers   bat           Sydney Sixers   runs
# 32 Melbourne Stars Melbourne Stars field         Melbourne Stars runs
# ...

# %%
count(bbl %>% group_by(toss_winner))
# Out:
#   toss_winner         n
# 1 Brisbane Heat       1
# 2 Melbourne Renegades 1
# 3 Melbourne Stars     5
# 4 Perth Scorchers     4
# 5 Sydney Sixers       3
# 6 Sydney Thunder      4

# %%
options(repr.plot.width = 10)
ggplot(data=bbl,aes(x=toss_winner,fill=toss_winner)) + geom_bar()
# Out:
# plot without title

# %%
count(bbl %>% group_by(toss_decision))
# Out:
#   toss_decision n
# 1 bat            5
# 2 field         13

# %%
options(repr.plot.width = 10)
ggplot(data=bbl,aes(x=toss_decision,fill=toss_decision)) + geom_bar()
# Out:
# plot without title

# %%
options(repr.plot.width = 13)
ggplot(data=bbl,aes(x=result_margin,fill=	winner)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
count(bbl %>% group_by(winner))
# Out:
#   winner              n
# 1 Adelaide Strikers   1
# 2 Brisbane Heat       3
# 3 Melbourne Renegades 2
# 4 Melbourne Stars     2
# 5 Perth Scorchers     3
# 6 Sydney Sixers       3
# 7 Sydney Thunder      4

# %%
bbl_counts <- bbl %>%
  count(toss_winner, result) %>%
  mutate(proportion = n / sum(n))
bbl_counts
# Out:
#   toss_winner         result  n proportion
# 1 Brisbane Heat       runs    1 0.05555556
# 2 Melbourne Renegades runs    1 0.05555556
# 3 Melbourne Stars     runs    5 0.27777778
# 4 Perth Scorchers     runs    1 0.05555556
# 5 Perth Scorchers     wickets 3 0.16666667
# 6 Sydney Sixers       runs    2 0.11111111
# 7 Sydney Sixers       wickets 1 0.05555556
# 8 Sydney Thunder      runs    2 0.11111111
# 9 Sydney Thunder      wickets 2 0.11111111

# %%
ggplot(bbl_counts, aes(x = "", y = proportion, fill = result)) +
  geom_bar(stat = "identity", width = 1) +
  coord_polar("y", start = 0) +
  labs(fill = "Match Result") +
  theme_void()
# Out:
# plot without title

# %%
head(bbl,2)
# Out:
#    id     city   date       player_of_match
# 16 524933 Sydney 1/8/2012   MA Starc
# 32 571236 Perth  12/12/2012 SL Malinga
#    venue                                        neutral_venue team1
# 16 Stadium Australia                            0             Sydney Thunder
# 32 Western Australia Cricket Association Ground 0             Perth Scorchers
#    team2           toss_winner     toss_decision winner          result
# 16 Sydney Sixers   Sydney Sixers   bat           Sydney Sixers   runs
# 32 Melbourne Stars Melbourne Stars field         Melbourne Stars runs
#    result_margin eliminator method umpire1      umpire2
# 16 17            N          D/L    BNJ Oxenford PR Reiffel
# 32 24            N          D/L    IH Lock      JD Ward

# %%
toss_winner=bbl %>% filter(toss_winner == winner)

# %%
head(toss_winner,5)
# Out:
#   id      city     date       player_of_match
# 1  524933 Sydney   1/8/2012   MA Starc
# 2  571236 Perth    12/12/2012 SL Malinga
# 3  571241 Brisbane 12/18/2012 NM Coulter-Nile
# 4  571265 Perth    2/5/2013   SE Marsh
# 5 1152559 Sydney   2/2/2019   DP Hughes
#   venue                                        neutral_venue team1
# 1 Stadium Australia                            0             Sydney Thunder
# 2 Western Australia Cricket Association Ground 0             Perth Scorchers
# 3 Brisbane Cricket Ground, Woolloongabba       0             Brisbane Heat
# 4 Western Australia Cricket Association Ground 0             Perth Scorchers
# 5 Sydney Cricket Ground                        0             Sydney Sixers
#   team2           toss_winner     toss_decision winner          result
# 1 Sydney Sixers   Sydney Sixers   bat           Sydney Sixers   runs
# 2 Melbourne Stars Melbourne Stars field         Melbourne Stars runs
# ...

# %%
toss_winner %>% select("toss_winner","winner")
# Out:
#    toss_winner         winner
# 1  Sydney Sixers       Sydney Sixers
# 2  Melbourne Stars     Melbourne Stars
# 3  Perth Scorchers     Perth Scorchers
# 4  Perth Scorchers     Perth Scorchers
# 5  Sydney Sixers       Sydney Sixers
# 6  Sydney Thunder      Sydney Thunder
# 7  Melbourne Stars     Melbourne Stars
# 8  Brisbane Heat       Brisbane Heat
# 9  Melbourne Renegades Melbourne Renegades
# 10 Sydney Thunder      Sydney Thunder

# %%
toss_winner %>% filter(toss_decision == "bat")
# Out:
#   id      city     date      player_of_match venue
# 1  524933 Sydney   1/8/2012  MA Starc        Stadium Australia
# 2 1195597 Sydney   1/6/2020  T Banton        Sydney Showground Stadium
# 3 1195609 Canberra 1/15/2020 SB Harper       Manuka Oval
#   neutral_venue team1          team2               toss_winner
# 1 0             Sydney Thunder Sydney Sixers       Sydney Sixers
# 2 0             Sydney Thunder Brisbane Heat       Brisbane Heat
# 3 0             Sydney Thunder Melbourne Renegades Melbourne Renegades
#   toss_decision winner              result result_margin eliminator method
# 1 bat           Sydney Sixers       runs   17            N          D/L
# 2 bat           Brisbane Heat       runs   16            N          D/L
# 3 bat           Melbourne Renegades runs   12            N          D/L
#   umpire1      umpire2
# 1 BNJ Oxenford PR Reiffel
# 2 GJ Davidson  SD Fry
# 3 SD Fry       DM Koch

# %%
toss_winner %>% filter(toss_decision == "field")
# Out:
#   id      city       date       player_of_match
# 1  571236 Perth      12/12/2012 SL Malinga
# 2  571241 Brisbane   12/18/2012 NM Coulter-Nile
# 3  571265 Perth      2/5/2013   SE Marsh
# 4 1152559 Sydney     2/2/2019   DP Hughes
# 5 1152565 Canberra   2/9/2019   PJ Cummins
# 6 1195588 Launceston 12/30/2019 NM Coulter-Nile
# 7 1195614 Sydney     1/18/2020  CH Morris
#   venue                                        neutral_venue team1
# 1 Western Australia Cricket Association Ground 0             Perth Scorchers
# 2 Brisbane Cricket Ground, Woolloongabba       0             Brisbane Heat
# 3 Western Australia Cricket Association Ground 0             Perth Scorchers
# 4 Sydney Cricket Ground                        0             Sydney Sixers
# 5 Manuka Oval                                  0             Sydney Thunder
# 6 Aurora Stadium                               0             Hobart Hurricanes
# 7 Sydney Showground Stadium                    0             Sydney Thunder
# ...

# %%
count(toss_winner %>% group_by(winner))
# Out:
#   winner              n
# 1 Brisbane Heat       1
# 2 Melbourne Renegades 1
# 3 Melbourne Stars     2
# 4 Perth Scorchers     2
# 5 Sydney Sixers       2
# 6 Sydney Thunder      2

# %%
options(repr.plot.height = 7)
options(repr.plot.width = 13)
ggplot(data=toss_winner,aes(x=winner)) + geom_bar(fill="orange")
# Out:
# plot without title

# %%
toss_winner
# Out:
# Adding missing grouping variables: `winner`
#   winner              n
# 1 Brisbane Heat       1
# 2 Melbourne Renegades 1
# 3 Melbourne Stars     2
# 4 Perth Scorchers     2
# 5 Sydney Sixers       2
# 6 Sydney Thunder      2

# %%
count(toss_winner %>% group_by(player_of_match))
# Out:
#   player_of_match n
# 1 CH Morris       1
# 2 DP Hughes       1
# 3 MA Starc        1
# 4 NM Coulter-Nile 2
# 5 PJ Cummins      1
# 6 SB Harper       1
# 7 SE Marsh        1
# 8 SL Malinga      1
# 9 T Banton        1
